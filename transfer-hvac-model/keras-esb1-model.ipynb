# %% [markdown]
# <h1 style="color:#27469c"> Improved ESB Tower 1 Model </h1>
#
# 1. Recreating the ESB Tower 1 model in keras (using LSTM) instead of scikit learn
# 2. Generalizing code
#
# Following https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %% [markdown]
# <h2 style="color:#27469c">Load packages and data</h2>

# %%
# Load Packages
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Activation
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error
from matplotlib import pyplot

# %%
# load cleaned up dataset
datapath = '../esb1-model/data'
df = pd.read_csv(f'{datapath}/results/prepared_data.csv', index_col='time')

# set index column as datetime object (dealing with timeseries data)
df.index.name = 'time'
df.index = pd.to_datetime(df.index)

# copied features and target from esb1-model
features = ['ESB_Tower_1 enteringWaterTemp', 'ESB_Tower_1 outdoorAirHumidity', 'ESB_Tower_1 outdoorAirDryBulb', 'ESB_Tower_1 outdoorAirWetBulb', 'Cell_1aFan vfdPercent', 'leavingWaterTemp_ratio', 'efficiency_rolling_mean']
targets = ['ESB_Tower_1 leavingWaterTemp']

# create final dataframe that includes only relevant features and targets
df = df[features].join(df[targets], on='time')

# %% [markdown]
# <h2 style="color:#27469c">Frame time series as a supervised learning dataset</h2>

# %%
def series_to_supervised(df, n_in=1, n_out=1, dropnan=True, target_names=df.columns):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
    data: Sequence of observations as a list or NumPy array.
    n_in: Number of lag observations as input (X).
    n_out: Number of observations as output (y).
    dropnan: Boolean whether or not to drop rows with NaN values.
    target_names: List of target variables to be predicted
    Returns:
    Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = df.shape[1]
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [(f"{df.columns[j]}(t-{i})") for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df[target_names].shift(-i))
        print(target_names)
        if i == 0:
            names += [(f"{df.columns[j]}(t)") for j in range(n_vars) if df.columns[j] in target_names]
        else:
            names += [(f"{df.columns[j]}(t+{i})") for j in range(n_vars) if df.columns[j] in target_names]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset as array
values = df.values
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_df = pd.DataFrame(scaler.fit_transform(values), columns=df.columns, index=df.index)

# frame time series dataset for supervised learning
reframed_df = series_to_supervised(scaled_df, 1, 1, target_names=['ESB_Tower_1 leavingWaterTemp'])
reframed_df
# Out:
# ['ESB_Tower_1 leavingWaterTemp']
#                            ESB_Tower_1 enteringWaterTemp(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                            0.537222
# 2019-05-17 16:50:00+00:00                            0.713371
# 2019-05-17 16:55:00+00:00                            0.723823
# 2019-05-17 17:00:00+00:00                            0.714243
# 2019-05-17 17:05:00+00:00                            0.694587
# ...                                                       ...
# 2020-01-01 04:40:00+00:00                            0.179032
# 2020-01-01 04:50:00+00:00                            0.179127
# 2020-01-01 05:00:00+00:00                            0.179106
# 2020-01-01 05:25:00+00:00                            0.178766
# 2020-01-01 05:35:00+00:00                            0.170768
#
#                            ESB_Tower_1 outdoorAirHumidity(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                             0.368177
# 2019-05-17 16:50:00+00:00                             0.375339
# 2019-05-17 16:55:00+00:00                             0.378388
# 2019-05-17 17:00:00+00:00                             0.377786
# 2019-05-17 17:05:00+00:00                             0.358970
# ...                                                        ...
# 2020-01-01 04:40:00+00:00                             0.364278
# 2020-01-01 04:50:00+00:00                             0.352227
# 2020-01-01 05:00:00+00:00                             0.351676
# 2020-01-01 05:25:00+00:00                             0.347363
# 2020-01-01 05:35:00+00:00                             0.352035
#
#                            ESB_Tower_1 outdoorAirDryBulb(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                            0.807534
# 2019-05-17 16:50:00+00:00                            0.807534
# 2019-05-17 16:55:00+00:00                            0.807534
# 2019-05-17 17:00:00+00:00                            0.807534
# 2019-05-17 17:05:00+00:00                            0.807534
# ...                                                       ...
# 2020-01-01 04:40:00+00:00                            0.301938
# 2020-01-01 04:50:00+00:00                            0.301938
# 2020-01-01 05:00:00+00:00                            0.305736
# 2020-01-01 05:25:00+00:00                            0.305736
# 2020-01-01 05:35:00+00:00                            0.305736
#
#                            ESB_Tower_1 outdoorAirWetBulb(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                            0.813007
# 2019-05-17 16:50:00+00:00                            0.812377
# 2019-05-17 16:55:00+00:00                            0.815557
# 2019-05-17 17:00:00+00:00                            0.819851
# 2019-05-17 17:05:00+00:00                            0.812134
# ...                                                       ...
# 2020-01-01 04:40:00+00:00                            0.297816
# 2020-01-01 04:50:00+00:00                            0.297285
# 2020-01-01 05:00:00+00:00                            0.299281
# 2020-01-01 05:25:00+00:00                            0.299157
# 2020-01-01 05:35:00+00:00                            0.299133
#
#                            Cell_1aFan vfdPercent(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                    1.000000
# 2019-05-17 16:50:00+00:00                    1.000000
# 2019-05-17 16:55:00+00:00                    1.000000
# 2019-05-17 17:00:00+00:00                    1.000000
# 2019-05-17 17:05:00+00:00                    1.000000
# ...                                               ...
# 2020-01-01 04:40:00+00:00                    0.026044
# 2020-01-01 04:50:00+00:00                    0.032557
# 2020-01-01 05:00:00+00:00                    0.025657
# 2020-01-01 05:25:00+00:00                    0.011471
# 2020-01-01 05:35:00+00:00                    0.000000
#
#                            leavingWaterTemp_ratio(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                     0.508960
# 2019-05-17 16:50:00+00:00                     0.508960
# 2019-05-17 16:55:00+00:00                     0.508960
# 2019-05-17 17:00:00+00:00                     0.234676
# 2019-05-17 17:05:00+00:00                     0.234676
# ...                                                ...
# 2020-01-01 04:40:00+00:00                     0.221217
# 2020-01-01 04:50:00+00:00                     0.221217
# 2020-01-01 05:00:00+00:00                     0.221217
# 2020-01-01 05:25:00+00:00                     0.234676
# 2020-01-01 05:35:00+00:00                     0.234676
#
#                            efficiency_rolling_mean(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                      0.439184
# 2019-05-17 16:50:00+00:00                      0.439189
# 2019-05-17 16:55:00+00:00                      0.439210
# 2019-05-17 17:00:00+00:00                      0.439219
# 2019-05-17 17:05:00+00:00                      0.439208
# ...                                                 ...
# 2020-01-01 04:40:00+00:00                      0.319331
# 2020-01-01 04:50:00+00:00                      0.319229
# 2020-01-01 05:00:00+00:00                      0.319126
# 2020-01-01 05:25:00+00:00                      0.319079
# 2020-01-01 05:35:00+00:00                      0.318872
#
#                            ESB_Tower_1 leavingWaterTemp(t-1)  \
# time
# 2019-05-17 16:45:00+00:00                           0.345625
# 2019-05-17 16:50:00+00:00                           0.345625
# 2019-05-17 16:55:00+00:00                           0.345625
# 2019-05-17 17:00:00+00:00                           0.345625
# 2019-05-17 17:05:00+00:00                           0.345625
# ...                                                      ...
# 2020-01-01 04:40:00+00:00                           0.208596
# 2020-01-01 04:50:00+00:00                           0.208596
# 2020-01-01 05:00:00+00:00                           0.208596
# 2020-01-01 05:25:00+00:00                           0.208596
# 2020-01-01 05:35:00+00:00                           0.208596
#
#                            ESB_Tower_1 leavingWaterTemp(t)
# time
# 2019-05-17 16:45:00+00:00                         0.345625
# 2019-05-17 16:50:00+00:00                         0.345625
# 2019-05-17 16:55:00+00:00                         0.345625
# 2019-05-17 17:00:00+00:00                         0.345625
# 2019-05-17 17:05:00+00:00                         0.345625
# ...                                                    ...
# 2020-01-01 04:40:00+00:00                         0.208596
# 2020-01-01 04:50:00+00:00                         0.208596
# 2020-01-01 05:00:00+00:00                         0.208596
# 2020-01-01 05:25:00+00:00                         0.208596
# 2020-01-01 05:35:00+00:00                         0.208596
#
# [40388 rows x 9 columns]

# %% [markdown]
# <h2 style="color:#27469c">Split into Training and Testing</h2>

# %%
tss = TimeSeriesSplit(n_splits = 3)
X = reframed_df.drop([f'{target}(t)' for target in targets], axis=1) # drop target columns
y = reframed_df[[f'{target}(t)' for target in targets]] # only have target columns

for train_index, test_index in tss.split(X): # split into training and testing
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index,:]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = X_train.values
test_X = X_test.values
train_y = y_train.values
test_y = y_test.values

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

# %% [markdown]
# <h2 style="color:#27469c">Create and Train Model</h2>

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# %%
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 421/421 - 2s - loss: 0.0463 - val_loss: 0.0700 - 2s/epoch - 5ms/step
# Epoch 2/50
# 421/421 - 1s - loss: 0.0345 - val_loss: 0.0644 - 617ms/epoch - 1ms/step
# Epoch 3/50
# 421/421 - 1s - loss: 0.0320 - val_loss: 0.0635 - 657ms/epoch - 2ms/step
# Epoch 4/50
# 421/421 - 1s - loss: 0.0309 - val_loss: 0.0597 - 597ms/epoch - 1ms/step
# Epoch 5/50
# 421/421 - 1s - loss: 0.0298 - val_loss: 0.0583 - 577ms/epoch - 1ms/step
# Epoch 6/50
# 421/421 - 1s - loss: 0.0290 - val_loss: 0.0560 - 670ms/epoch - 2ms/step
# Epoch 7/50
# 421/421 - 1s - loss: 0.0282 - val_loss: 0.0504 - 763ms/epoch - 2ms/step
# Epoch 8/50
# 421/421 - 1s - loss: 0.0270 - val_loss: 0.0450 - 703ms/epoch - 2ms/step
# Epoch 9/50
# 421/421 - 1s - loss: 0.0261 - val_loss: 0.0409 - 732ms/epoch - 2ms/step
# Epoch 10/50
# 421/421 - 1s - loss: 0.0248 - val_loss: 0.0381 - 715ms/epoch - 2ms/step
# Epoch 11/50
# 421/421 - 1s - loss: 0.0232 - val_loss: 0.0350 - 627ms/epoch - 1ms/step
# Epoch 12/50
# 421/421 - 1s - loss: 0.0222 - val_loss: 0.0304 - 639ms/epoch - 2ms/step
# Epoch 13/50
# 421/421 - 1s - loss: 0.0207 - val_loss: 0.0256 - 594ms/epoch - 1ms/step
# Epoch 14/50
# 421/421 - 1s - loss: 0.0192 - val_loss: 0.0211 - 583ms/epoch - 1ms/step
# Epoch 15/50
# 421/421 - 1s - loss: 0.0178 - val_loss: 0.0149 - 659ms/epoch - 2ms/step
# Epoch 16/50
# 421/421 - 1s - loss: 0.0164 - val_loss: 0.0088 - 605ms/epoch - 1ms/step
# Epoch 17/50
# 421/421 - 1s - loss: 0.0144 - val_loss: 0.0055 - 625ms/epoch - 1ms/step
# Epoch 18/50
# 421/421 - 1s - loss: 0.0127 - val_loss: 0.0089 - 599ms/epoch - 1ms/step
# Epoch 19/50
# 421/421 - 1s - loss: 0.0115 - val_loss: 0.0134 - 594ms/epoch - 1ms/step
# Epoch 20/50
# 421/421 - 1s - loss: 0.0095 - val_loss: 0.0156 - 593ms/epoch - 1ms/step
# Epoch 21/50
# 421/421 - 1s - loss: 0.0075 - val_loss: 0.0175 - 591ms/epoch - 1ms/step
# Epoch 22/50
# 421/421 - 1s - loss: 0.0066 - val_loss: 0.0180 - 591ms/epoch - 1ms/step
# Epoch 23/50
# 421/421 - 1s - loss: 0.0054 - val_loss: 0.0207 - 589ms/epoch - 1ms/step
# Epoch 24/50
# 421/421 - 1s - loss: 0.0051 - val_loss: 0.0179 - 592ms/epoch - 1ms/step
# Epoch 25/50
# 421/421 - 1s - loss: 0.0049 - val_loss: 0.0223 - 588ms/epoch - 1ms/step
# Epoch 26/50
# 421/421 - 1s - loss: 0.0051 - val_loss: 0.0232 - 623ms/epoch - 1ms/step
# Epoch 27/50
# 421/421 - 1s - loss: 0.0056 - val_loss: 0.0170 - 631ms/epoch - 1ms/step
# Epoch 28/50
# 421/421 - 1s - loss: 0.0055 - val_loss: 0.0176 - 620ms/epoch - 1ms/step
# Epoch 29/50
# 421/421 - 1s - loss: 0.0045 - val_loss: 0.0186 - 643ms/epoch - 2ms/step
# Epoch 30/50
# 421/421 - 1s - loss: 0.0048 - val_loss: 0.0233 - 630ms/epoch - 1ms/step
# Epoch 31/50
# 421/421 - 1s - loss: 0.0044 - val_loss: 0.0222 - 627ms/epoch - 1ms/step
# Epoch 32/50
# 421/421 - 1s - loss: 0.0045 - val_loss: 0.0265 - 599ms/epoch - 1ms/step
# Epoch 33/50
# 421/421 - 1s - loss: 0.0053 - val_loss: 0.0193 - 621ms/epoch - 1ms/step
# Epoch 34/50
# 421/421 - 1s - loss: 0.0056 - val_loss: 0.0243 - 639ms/epoch - 2ms/step
# Epoch 35/50
# 421/421 - 1s - loss: 0.0055 - val_loss: 0.0187 - 691ms/epoch - 2ms/step
# Epoch 36/50
# 421/421 - 1s - loss: 0.0057 - val_loss: 0.0187 - 800ms/epoch - 2ms/step
# Epoch 37/50
# 421/421 - 1s - loss: 0.0064 - val_loss: 0.0192 - 626ms/epoch - 1ms/step
# Epoch 38/50
# 421/421 - 1s - loss: 0.0071 - val_loss: 0.0228 - 643ms/epoch - 2ms/step
# Epoch 39/50
# 421/421 - 1s - loss: 0.0075 - val_loss: 0.0170 - 615ms/epoch - 1ms/step
# Epoch 40/50
# 421/421 - 1s - loss: 0.0068 - val_loss: 0.0247 - 592ms/epoch - 1ms/step
# Epoch 41/50
# 421/421 - 1s - loss: 0.0078 - val_loss: 0.0223 - 594ms/epoch - 1ms/step
# Epoch 42/50
# 421/421 - 1s - loss: 0.0076 - val_loss: 0.0240 - 594ms/epoch - 1ms/step
# Epoch 43/50
# 421/421 - 1s - loss: 0.0065 - val_loss: 0.0202 - 622ms/epoch - 1ms/step
# Epoch 44/50
# 421/421 - 1s - loss: 0.0071 - val_loss: 0.0237 - 602ms/epoch - 1ms/step
# Epoch 45/50
# 421/421 - 1s - loss: 0.0078 - val_loss: 0.0228 - 645ms/epoch - 2ms/step
# Epoch 46/50
# 421/421 - 1s - loss: 0.0075 - val_loss: 0.0218 - 750ms/epoch - 2ms/step
# Epoch 47/50
# 421/421 - 1s - loss: 0.0073 - val_loss: 0.0173 - 779ms/epoch - 2ms/step
# Epoch 48/50
# 421/421 - 1s - loss: 0.0078 - val_loss: 0.0197 - 638ms/epoch - 2ms/step
# Epoch 49/50
# 421/421 - 1s - loss: 0.0080 - val_loss: 0.0227 - 623ms/epoch - 1ms/step
# Epoch 50/50
# 421/421 - 1s - loss: 0.0067 - val_loss: 0.0229 - 624ms/epoch - 1ms/step

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.legend()
pyplot.show()

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# Out:
# 316/316 [==============================] - 1s 684us/step

# %%
# calculate RMSE
mabs_error = mean_absolute_error(test_y, yhat)
msq_error = mean_squared_error(test_y, yhat)

rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.771
